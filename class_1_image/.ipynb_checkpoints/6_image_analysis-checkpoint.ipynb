# %%
import imageio as iio
import numpy as np 
import matplotlib.pyplot as plt

data = np.average(iio.imread('moon.png'), axis=-1)

# %%
im = plt.imshow(data, cmap='gray')
x, y = np.unravel_index(data.argmax(), data.shape)
plt.plot([y], [x], marker='o', markersize=3, color="red")

print(y, x)
plt.show()
# Out:
# 674 356

# %%
im = plt.imshow(data, cmap='gray')
tmp_data = data.copy()
tmp_data /= np.max(tmp_data)
pos = np.where(data)
x = int(np.average(pos[0], weights=data[pos]))
y = int(np.average(pos[1], weights=data[pos]))
plt.plot([y], [x], marker='o', markersize=3, color="red")

print(y, x)
plt.show()
# Out:
# 664 348

# %%
from scipy.optimize import curve_fit

def gauss(x, *p):
    A, mu, sigma = p
    return A*np.exp(-(x-mu)**2/(2.*sigma**2))

data = data.astype(int)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))
im = axs[0,0].imshow(data, cmap='gray')
axs[-1, -1].axis('off')

x_ = np.arange(data.shape[0])
# func_ = np.log(np.max(data, axis=1))
func_ = np.sum(data**2, axis=1)
axs[0,1].plot(func_, x_)
coeff_1, _ = curve_fit(gauss, x_, func_, p0=[1., 0., 1.])
axs[0,1].plot(gauss(x_, *coeff_1), x_)

x_ = np.arange(data.shape[1])
# func_ = np.log(np.max(data, axis=0))
func_ = np.sum(data**2, axis=0)
axs[1,0].plot(x_, func_)
coeff_2, _ = curve_fit(gauss, x_, func_, p0=[1., 0., 1.])
axs[1,0].plot(x_, gauss(x_, *coeff_2))

x, y = coeff_1[1], coeff_2[1]
axs[0,0].plot([y], [x], marker='o', markersize=3, color="red")
fig.tight_layout()
plt.show()

# %%
from skimage import io, color, measure, draw, img_as_bool
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

tmp_data = data.copy()
data[data < 128] = 0
tmp_data = img_as_bool(tmp_data)

y0, x0 = bubble.centroid
r = bubble.major_axis_length / 2.

def cost(params):
    img, x0, y0, r = params
    coords = draw.disk((y0, x0), r, shape=img.shape)
    template = np.zeros_like(img)
    template[coords] = 1
    return -np.sum(template == img)

x0, y0, r = optimize.fmin(cost, (tmp_data, x, y, 100))

import matplotlib.pyplot as plt

f, ax = plt.subplots()
circle = plt.Circle((x0, y0), r)
ax.imshow(image, cmap='gray', interpolation='nearest')
ax.add_artist(circle)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [40], in <cell line: 10>()
#       8 image = img_as_bool(data)
#       9 regions = measure.regionprops(measure.label(image))
# ---> 10 bubble = regions[0]
#      12 y0, x0 = bubble.centroid
#      13 r = bubble.major_axis_length / 2.
#
# IndexError: list index out of range
