# %%
import os
import numpy as np 
import matplotlib.pyplot as plt
import nibabel as nib

from utils import split_name_with_nii, get_slice, get_nifti_data, get_nifti_header_info, summarize_intensities

# %%
np.set_printoptions(suppress=True)
for root, dirs, files in os.walk("./", topdown=False):
    for name in files:
        path = os.path.join(root, name)
        base, ext = split_name_with_nii(path)
        if ext in ['.nii', '.nii.gz']:
            print(path)
            curr_img = nib.load(path)
            curr_data = get_nifti_data(curr_img)
            if curr_data.ndim > 3:
                last_dim = curr_data.shape[-1]
                curr_data = curr_data[..., 0]
            else:
                last_dim = 0

            aff, dims, vox_sizes, vox_order = \
                get_nifti_header_info(curr_img)
            fig, axs = plt.subplots(1, 3, figsize=(9, 27))
            for i, axis in enumerate(['axial', 'coronal', 'sagittal']):
                curr_slice = get_slice(curr_data, axis)
                axs[i].imshow(curr_slice, cmap='gray')
            print(np.round(aff, 3))
            print(dims, np.round(vox_sizes, 3), vox_order, curr_data.dtype)
            print(summarize_intensities(curr_data))
            if last_dim:
                print('4D size: {}'.format(last_dim))
            plt.show()
            print('===============================')
# Out:
# ./test_dataset/swi/sub-X_ses-Y_part-mag_GRE.nii.gz
# [[   0.896    0.051   -0.109  -77.211]
#  [  -0.061    0.873   -0.451  -58.106]
#  [   0.036    0.205    1.945 -111.328]
#  [   0.       0.       0.       1.   ]]
# [192 256  72] [0.898 0.898 2.   ] RAS int16
# (3538944, 3448174, 63.313, 74.461, 21.0, 119.0, 732, 1)
# ===============================
# ./test_dataset/swi/sub-X_ses-Y_swi.nii.gz
# [[   0.896    0.051   -0.109  -77.211]
#  [  -0.061    0.873   -0.451  -58.106]
#  [   0.036    0.205    1.945 -111.328]
#  [   0.       0.       0.       1.   ]]
# [192 256  72] [0.898 0.898 2.   ] RAS int16
# (3538944, 3109993, 62.921, 73.611, 20.0, 124.0, 708, 1)
# ===============================
# ./test_dataset/swi/sub-X_ses-Y_part-phase_GRE.nii.gz
# [[   0.896    0.051   -0.109  -77.211]
#  [  -0.061    0.873   -0.451  -58.106]
#  [   0.036    0.205    1.945 -111.328]
#  [   0.       0.       0.       1.   ]]
# [192 256  72] [0.898 0.898 2.   ] RAS float64
# (3538944, 3470801, 770.638, 915.641, 406.0, 958.0, 4094.0, 2.0)
# ===============================
# ./test_dataset/swi/sub-X_ses-Y_minIP.nii.gz
# [[   0.896    0.051   -0.109  -77.592]
#  [  -0.061    0.873   -0.451  -59.685]
#  [   0.036    0.205    1.945 -104.519]
#  [   0.       0.       0.       1.   ]]
# [192 256  65] [0.898 0.898 2.   ] RAS int16
# (3194880, 1769644, 60.405, 66.692, 19.0, 126.0, 245, 1)
# ===============================
# ./test_dataset/fmap/sub-X_ses-Y_acq-echo1_run-01_fieldmap.nii.gz
# [[ -2.      0.     -0.    119.762]
#  [ -0.      2.     -0.    -83.18 ]
#  [  0.      0.      2.    -90.13 ]
#  [  0.      0.      0.      1.   ]]
# [112 112  80] [2. 2. 2.] LAS int16
# (1003520, 994560, 321.336, 390.537, 67.0, 588.0, 2496, 3)
# ===============================
# ./test_dataset/fmap/sub-X_ses-Y_run-02_fieldmap.nii.gz
# [[ -2.      0.     -0.    119.762]
#  [ -0.      2.     -0.    -83.18 ]
#  [  0.      0.      2.    -90.13 ]
#  [  0.      0.      0.      1.   ]]
# [112 112  80] [2. 2. 2.] LAS float64
# (1003520, 993986, 1351.602, 1163.21, 966.0, 1812.0, 4092.0, 2.0)
# ===============================
# ./test_dataset/fmap/sub-X_ses-Y_acq-echo2_run-01_fieldmap.nii.gz
# [[ -2.      0.     -0.    119.762]
#  [ -0.      2.     -0.    -83.18 ]
#  [  0.      0.      2.    -90.13 ]
#  [  0.      0.      0.      1.   ]]
# [112 112  80] [2. 2. 2.] LAS int16
# (1003520, 994560, 296.671, 364.53, 66.0, 514.0, 2433, 6)
# ===============================
# ./test_dataset/anat/sub-X_ses-Y_T2w.nii.gz
# [[   0.997    0.057   -0.054  -77.061]
#  [  -0.068    0.972   -0.226  -57.864]
#  [   0.04     0.229    0.973 -168.827]
#  [   0.       0.       0.       1.   ]]
# [176 256 256] [1. 1. 1.] RAS int16
# (11534336, 9618564, 44.515, 61.987, 8.0, 75.0, 531, 1)
# ===============================
# ./test_dataset/anat/sub-X_ses-Y_T2star.nii.gz
# [[  -1.791    0.103   -0.272  123.452]
#  [   0.123    1.746   -1.128  -67.176]
#  [  -0.072    0.411    4.864 -119.187]
#  [   0.       0.       0.       1.   ]]
# [128 128  36] [1.797 1.797 5.   ] LAS int16
# (589824, 582727, 84.724, 189.939, 20.0, 15.0, 2668, 1)
# ===============================
# ./test_dataset/anat/sub-X_ses-Y_T1w.nii.gz
# [[   0.997    0.057   -0.054  -77.06 ]
#  [  -0.068    0.972   -0.226  -57.856]
#  [   0.04     0.229    0.973 -168.833]
#  [   0.       0.       0.       1.   ]]
# [176 256 256] [1. 1. 1.] RAS int16
# (11534336, 11108812, 70.111, 97.752, 11.0, 124.0, 718, 1)
# ===============================
# ./test_dataset/anat/sub-X_ses-Y_acq-TOF_angio.nii.gz
# [[  0.444   0.035  -0.037 -72.222]
#  [ -0.04    0.429  -0.17  -50.486]
#  [  0.015   0.119   0.626 -86.706]
#  [  0.      0.      0.      1.   ]]
# [352 448 108] [0.446 0.446 0.65 ] RAS int16
# (17031168, 16936281, 81.52, 52.232, 90.0, 92.0, 815, 1)
# ===============================
# ./test_dataset/anat/sub-X_ses-Y_acq-TSE_T2w.nii.gz
# [[  -0.997    0.057   -0.217  134.669]
#  [   0.068    0.972   -0.902  -85.419]
#  [  -0.04     0.229    3.891 -104.8  ]
#  [   0.       0.       0.       1.   ]]
# [256 256  36] [1. 1. 4.] LAS int16
# (2359296, 2160803, 146.039, 239.794, 6.0, 257.0, 1768, 1)
# ===============================
# ./test_dataset/func/sub-X_ses-Y_task-rest_run-02_bold.nii.gz
# [[  -3.988    0.229   -0.217  134.852]
#  [   0.273    3.887   -0.902  -82.493]
#  [  -0.159    0.914    3.891 -104.112]
#  [   0.       0.       0.       1.   ]]
# [64 64 36] [4. 4. 4.] LAS int16
# (147456, 145094, 94.761, 181.726, 10.0, 49.0, 1227, 1)
# 4D size: 164
# ===============================
# ./test_dataset/func/sub-X_ses-Y_task-rest_run-01_bold.nii.gz
# [[  -3.988    0.229   -0.217  134.852]
#  [   0.273    3.887   -0.902  -82.493]
#  [  -0.159    0.914    3.891 -104.112]
#  [   0.       0.       0.       1.   ]]
# [64 64 36] [4. 4. 4.] LAS int16
# (147456, 145087, 93.436, 180.043, 10.0, 48.0, 1143, 1)
# 4D size: 164
# ===============================
# ./test_dataset/dwi/sub-X_ses-Y_run-02_dwi.nii.gz
# [[ -2.      0.     -0.    119.762]
#  [ -0.      2.     -0.    -83.18 ]
#  [  0.      0.      2.    -90.13 ]
#  [  0.      0.      0.      1.   ]]
# [112 112  80] [2. 2. 2.] LAS int16
# (1003520, 994434, 123.79, 242.76, 42.0, 61.0, 4095, 1)
# 4D size: 24
# ===============================
# ./test_dataset/dwi/sub-X_ses-Y_run-01_dwi_mask.nii.gz
# [[ -2.      0.     -0.    119.762]
#  [ -0.      2.     -0.    -83.18 ]
#  [  0.      0.      2.    -90.13 ]
#  [  0.      0.      0.      1.   ]]
# [112 112  80] [2. 2. 2.] LAS uint8
# (1003520, 194616, 1.0, 0.0, 1.0, 0.0, 1, 1)
# ===============================
# ./test_dataset/dwi/sub-X_ses-Y_run-01_dwi.nii.gz
# [[ -2.      0.     -0.    119.762]
#  [ -0.      2.     -0.    -83.18 ]
#  [  0.      0.      2.    -90.13 ]
#  [  0.      0.      0.      1.   ]]
# [112 112  80] [2. 2. 2.] LAS int16
# (1003520, 994434, 122.006, 241.704, 42.0, 57.0, 4095, 1)
# 4D size: 24
# ===============================
# ./test_dataset/dwi/sub-X_ses-Y_run-02_dwi_mask.nii.gz
# [[ -2.      0.     -0.    119.762]
#  [ -0.      2.     -0.    -83.18 ]
#  [  0.      0.      2.    -90.13 ]
#  [  0.      0.      0.      1.   ]]
# [112 112  80] [2. 2. 2.] LAS uint8
# (1003520, 195113, 1.0, 0.0, 1.0, 0.0, 1, 1)
# ===============================
